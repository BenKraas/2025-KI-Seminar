# %%
# imports
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import geopandas as gpd
from pathlib import Path
import rasterio
from sklearn.model_selection import train_test_split

# %%
# Load raster data
tilenr = "02_04"
data_dir = Path("data") / "static" / tilenr
x_train_locations = [
    {"data": data_dir / f"SkyViewFactor_{tilenr}.tif", "name": "sky_view_factor", "NaN": -9999},
    {"data": data_dir / f"wall_height_{tilenr}.tif", "name": "wall_height", "NaN": -9999},
    {"data": data_dir / f"wall_aspect_{tilenr}.tif", "name": "wall_aspect", "NaN": -9999},
    {"data": data_dir / f"DO_landcover_3m_reclassified_final_{tilenr}.tif", "name": "landcover", "NaN": -9999},
]
y_train_location = {"data": data_dir / f"{tilenr}_Tmrt_3m_v0.6.0_2024_093_1000D.tif", "name": "Tmrt", "NaN": -9999}

# Load X_train rasters
X_train_data = {}
metadata = {}
for data_location in x_train_locations:
    with rasterio.open(data_location["data"]) as src:
        data = src.read(1).astype(np.float32)
        # Store original data statistics for denormalization later
        mask = data != data_location["NaN"]
        metadata[data_location["name"]] = {
            "min": np.nanmin(data[mask]),
            "max": np.nanmax(data[mask]),
            "mean": np.nanmean(data[mask]),
            "std": np.nanstd(data[mask])
        }
        # Handle NaN values
        data[data == data_location["NaN"]] = np.nan
        # Store the data in dictionary
        X_train_data[data_location["name"]] = data

# Load y_train raster
with rasterio.open(y_train_location["data"]) as src:
    y_data = src.read(1).astype(np.float32)
    # Store target metadata
    mask = y_data != y_train_location["NaN"]
    metadata[y_train_location["name"]] = {
        "min": np.nanmin(y_data[mask]),
        "max": np.nanmax(y_data[mask]),
        "mean": np.nanmean(y_data[mask]),
        "std": np.nanstd(y_data[mask]),
        "transform": src.transform,
        "crs": src.crs,
        "shape": src.shape
    }
    # Handle NaN values
    y_data[y_data == y_train_location["NaN"]] = np.nan

# Create valid data mask (where all inputs and target are valid)
valid_mask = np.ones_like(y_data, dtype=bool)
for data in X_train_data.values():
    valid_mask = valid_mask & ~np.isnan(data)
valid_mask = valid_mask & ~np.isnan(y_data)

# Apply normalization and NaN handling to features
X_train_normalized = []
for name, data in X_train_data.items():
    # Z-score normalization for continuous variables
    if name != "landcover":
        data_norm = (data - metadata[name]["mean"]) / metadata[name]["std"]
    else:
        # One-hot encoding would be better for categorical data like landcover
        # For simplicity, just use min-max scaling here
        data_norm = data / metadata[name]["max"]
    
    # Replace NaN with 0 after normalization
    data_norm = np.nan_to_num(data_norm, nan=0.0)
    X_train_normalized.append(data_norm)

# Stack features to create input tensor
X_train = np.stack(X_train_normalized, axis=-1)  # Shape: (height, width, num_channels)

# Normalize target variable
y_train = (y_data - metadata[y_train_location["name"]]["mean"]) / metadata[y_train_location["name"]]["std"]
y_train = np.nan_to_num(y_train, nan=0.0)
y_train = y_train[..., np.newaxis]  # Add channel dimension

# Apply valid mask if needed
# X_train = X_train[valid_mask]
# y_train = y_train[valid_mask]

# Reshape for deep learning models
X_train_reshaped = X_train.reshape(-1, X_train.shape[2])  # Flatten spatial dimensions
y_train_reshaped = y_train.reshape(-1, 1)

# Filter out invalid data points
valid_indices = ~np.isnan(y_train_reshaped).any(axis=1)
X_train_reshaped = X_train_reshaped[valid_indices]
y_train_reshaped = y_train_reshaped[valid_indices]

# Train-test split
X_train_split, X_val_split, y_train_split, y_val_split = train_test_split(
    X_train_reshaped, y_train_reshaped, test_size=0.2, random_state=42
)

# For CNN models, reshape back to spatial dimensions
# height, width = metadata[y_train_location["name"]]["shape"]
# X_train_cnn = X_train.reshape(1, height, width, X_train.shape[-1])  # Add batch dimension
# y_train_cnn = y_train.reshape(1, height, width, 1)

# Plot data for visualization
fig, axs = plt.subplots(2, 3, figsize=(15, 10))
axs = axs.flatten()

# Plot features
for i, (name, data) in enumerate(X_train_data.items()):
    if i < len(axs) - 1:
        im = axs[i].imshow(data, cmap="viridis")
        axs[i].set_title(name)
        plt.colorbar(im, ax=axs[i])

# Plot target
im = axs[-1].imshow(y_data, cmap="plasma")
axs[-1].set_title(y_train_location["name"])
plt.colorbar(im, ax=axs[-1])

plt.tight_layout()
plt.show()

# Print dataset information
print(f"Dataset shapes:")
print(f"Original data shape: {X_train.shape}")
print(f"Reshaped training data: {X_train_split.shape}")
print(f"Reshaped validation data: {X_val_split.shape}")
print(f"Number of valid data points: {valid_indices.sum()}")
print(f"Feature statistics:")
for name, stats in metadata.items():
    if name != y_train_location["name"]:
        print(f"  {name}: min={stats['min']:.2f}, max={stats['max']:.2f}, mean={stats['mean']:.2f}, std={stats['std']:.2f}")
# Out:
# Dataset shapes:
# Original data shape: (1000, 1000, 4)
# Reshaped training data: (800000, 4)
# Reshaped validation data: (200000, 4)
# Number of valid data points: 1000000
# Feature statistics:
#   sky_view_factor: min=0.01, max=1.00, mean=0.65, std=0.36
#   wall_height: min=0.00, max=28.94, mean=0.30, std=1.55
#   wall_aspect: min=0.00, max=359.99, mean=7.48, std=41.01
#   landcover: min=1.00, max=7.00, mean=3.79, std=1.91

# %%
import tensorflow as tf
import numpy as np
from tensorflow.keras import layers, models

# Keep the same model architecture
def create_unet_model(input_shape, num_features):
    """
    Create a U-Net model for raster data processing.
    
    Args:
        input_shape: Tuple of (height, width, num_features)
        num_features: Number of input features/bands
    
    Returns:
        Compiled Keras model
    """
    # Input layer
    inputs = layers.Input(shape=input_shape)
    
    # Encoder path
    # Level 1
    conv1 = layers.Conv2D(64, (3, 3), activation='relu', padding='same')(inputs)
    conv1 = layers.BatchNormalization()(conv1)
    conv1 = layers.Conv2D(64, (3, 3), activation='relu', padding='same')(conv1)
    conv1 = layers.BatchNormalization()(conv1)
    pool1 = layers.MaxPooling2D(pool_size=(2, 2))(conv1)
    
    # Level 2
    conv2 = layers.Conv2D(128, (3, 3), activation='relu', padding='same')(pool1)
    conv2 = layers.BatchNormalization()(conv2)
    conv2 = layers.Conv2D(128, (3, 3), activation='relu', padding='same')(conv2)
    conv2 = layers.BatchNormalization()(conv2)
    pool2 = layers.MaxPooling2D(pool_size=(2, 2))(conv2)
    
    # Level 3 (Bridge)
    conv3 = layers.Conv2D(256, (3, 3), activation='relu', padding='same')(pool2)
    conv3 = layers.BatchNormalization()(conv3)
    conv3 = layers.Conv2D(256, (3, 3), activation='relu', padding='same')(conv3)
    conv3 = layers.BatchNormalization()(conv3)
    
    # Decoder path
    # Level 2
    up2 = layers.Conv2DTranspose(128, (2, 2), strides=(2, 2), padding='same')(conv3)
    concat2 = layers.Concatenate()([up2, conv2])
    conv2_up = layers.Conv2D(128, (3, 3), activation='relu', padding='same')(concat2)
    conv2_up = layers.BatchNormalization()(conv2_up)
    conv2_up = layers.Conv2D(128, (3, 3), activation='relu', padding='same')(conv2_up)
    conv2_up = layers.BatchNormalization()(conv2_up)
    
    # Level 1
    up1 = layers.Conv2DTranspose(64, (2, 2), strides=(2, 2), padding='same')(conv2_up)
    concat1 = layers.Concatenate()([up1, conv1])
    conv1_up = layers.Conv2D(64, (3, 3), activation='relu', padding='same')(concat1)
    conv1_up = layers.BatchNormalization()(conv1_up)
    conv1_up = layers.Conv2D(64, (3, 3), activation='relu', padding='same')(conv1_up)
    conv1_up = layers.BatchNormalization()(conv1_up)
    
    # Output layer
    outputs = layers.Conv2D(1, (1, 1), activation='linear')(conv1_up)
    
    # Create model
    model = models.Model(inputs=inputs, outputs=outputs)
    
    # Compile model
    model.compile(
        optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
        loss='mean_squared_error',
        metrics=['mae', 'mse']
    )
    
    return model

# Modified training function for single sample data
def train_unet_model_patch_based(X_train, y_train, patch_size=64, batch_size=8, epochs=50):
    """
    Train the U-Net model using a patch-based approach, which is suitable when
    you have a single large raster but want to create multiple training samples.
    
    Args:
        X_train: Input features array with shape (height, width, num_features)
        y_train: Target array with shape (height, width, 1)
        patch_size: Size of the patches to extract (patch_size x patch_size)
        batch_size: Batch size for training
        epochs: Number of training epochs
    
    Returns:
        Trained model and training history
    """
    # Check if we have a single sample with batch dimension
    if len(X_train.shape) == 4 and X_train.shape[0] == 1:
        X_train = X_train[0]  # Remove batch dimension
    
    if len(y_train.shape) == 4 and y_train.shape[0] == 1:
        y_train = y_train[0]  # Remove batch dimension
    
    # Extract patches from the large raster
    print(f"Original data shape: X={X_train.shape}, y={y_train.shape}")
    
    # Generate patch indices
    height, width = X_train.shape[0], X_train.shape[1]
    num_features = X_train.shape[2]
    
    patches_X = []
    patches_y = []
    
    # Use a stride to create overlapping patches
    stride = patch_size // 2
    
    for i in range(0, height - patch_size + 1, stride):
        for j in range(0, width - patch_size + 1, stride):
            # Extract patch
            patch_X = X_train[i:i+patch_size, j:j+patch_size, :]
            patch_y = y_train[i:i+patch_size, j:j+patch_size, :]
            
            # Check if patch contains valid data (not all zeros or NaNs)
            if np.sum(np.isnan(patch_X)) == 0 and np.sum(np.isnan(patch_y)) == 0:
                if np.sum(patch_y) > 0:  # Ensure patch contains meaningful target data
                    patches_X.append(patch_X)
                    patches_y.append(patch_y)
    
    # Convert to numpy arrays
    X_patches = np.array(patches_X)
    y_patches = np.array(patches_y)
    
    print(f"Created {len(patches_X)} patches of size {patch_size}x{patch_size}")
    print(f"Patches shape: X={X_patches.shape}, y={y_patches.shape}")
    
    # Check if we have enough patches
    if len(patches_X) < 10:
        print("Warning: Very few patches created. Consider decreasing patch_size or stride.")
        if len(patches_X) == 0:
            raise ValueError("No valid patches could be created from the data.")
    
    # Create model with patch size
    model = create_unet_model((patch_size, patch_size, num_features), num_features)
    
    # Print model summary
    model.summary()
    
    # Add callbacks
    callbacks = [
        tf.keras.callbacks.EarlyStopping(
            monitor='loss', 
            patience=10, 
            restore_best_weights=True
        ),
        tf.keras.callbacks.ModelCheckpoint(
            filepath='best_unet_model.keras',
            monitor='loss',
            save_best_only=True
        ),
        tf.keras.callbacks.ReduceLROnPlateau(
            monitor='loss',
            factor=0.5,
            patience=5,
            min_lr=1e-6
        )
    ]
    
    # Train model with patches
    history = model.fit(
        X_patches, 
        y_patches,
        batch_size=batch_size,
        epochs=epochs,
        callbacks=callbacks,
        shuffle=True
    )
    
    return model, history, (X_patches, y_patches)

# Function to predict on the full raster using a patch-based approach
def predict_full_raster(model, X_data, patch_size=64, overlap=32):
    """
    Make predictions on a full raster by using a patch-based approach
    and stitching the results back together.
    
    Args:
        model: Trained U-Net model
        X_data: Input data (height, width, num_features)
        patch_size: Size of patches used for prediction
        overlap: Overlap between patches
        
    Returns:
        Full prediction raster
    """
    # Ensure X_data doesn't have batch dimension
    if len(X_data.shape) == 4 and X_data.shape[0] == 1:
        X_data = X_data[0]
    
    height, width, num_features = X_data.shape
    stride = patch_size - overlap
    
    # Create an empty output raster
    prediction = np.zeros((height, width, 1))
    weight_map = np.zeros((height, width, 1))
    
    # Create a weight matrix that gives higher weight to the center of patches
    weight_matrix = np.ones((patch_size, patch_size, 1))
    for i in range(patch_size):
        for j in range(patch_size):
            # Distance from center (0 to 1)
            di = abs(i - patch_size/2) / (patch_size/2)
            dj = abs(j - patch_size/2) / (patch_size/2)
            # Weight decreases from center to edge
            weight_matrix[i, j, 0] = (1 - di**2) * (1 - dj**2)
    
    # Make predictions on overlapping patches
    for i in range(0, height - patch_size + 1, stride):
        for j in range(0, width - patch_size + 1, stride):
            # Extract patch
            patch = X_data[i:i+patch_size, j:j+patch_size, :]
            
            # Add batch dimension
            patch = np.expand_dims(patch, axis=0)
            
            # Make prediction
            pred_patch = model.predict(patch)
            
            # Remove batch dimension
            pred_patch = pred_patch[0]
            
            # Add weighted prediction to output
            prediction[i:i+patch_size, j:j+patch_size, :] += pred_patch * weight_matrix
            weight_map[i:i+patch_size, j:j+patch_size, :] += weight_matrix
    
    # Normalize by weights
    mask = weight_map > 0
    prediction[mask] = prediction[mask] / weight_map[mask]
    
    return prediction

# Example of how to use these functions:

# After preparing your data
# X_train shape: (height, width, num_features)
# y_train shape: (height, width, 1)

# Train model with patch-based approach
model, history, (X_patches, y_patches) = train_unet_model_patch_based(
    X_train, 
    y_train, 
    patch_size=16, 
    batch_size=16, 
    epochs=100
)

# Visualize training history
import matplotlib.pyplot as plt
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(history.history['loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')

plt.subplot(1, 2, 2)
plt.plot(history.history['mae'])
plt.title('Model MAE')
plt.ylabel('MAE')
plt.xlabel('Epoch')
plt.tight_layout()
plt.show()

# Visualize a few patches
plt.figure(figsize=(12, 6))
for i in range(min(4, len(X_patches))):
    plt.subplot(2, 4, i+1)
    plt.imshow(X_patches[i, :, :, 0], cmap='viridis')
    plt.title(f'Input Patch {i}')
    
    plt.subplot(2, 4, i+5)
    plt.imshow(y_patches[i, :, :, 0], cmap='plasma')
    plt.title(f'Target Patch {i}')
plt.tight_layout()
plt.show()

# Make prediction on the full raster
prediction = predict_full_raster(model, X_train, patch_size=16, overlap=32)

# Visualize result
plt.figure(figsize=(15, 5))
plt.subplot(1, 3, 1)
plt.imshow(X_train[:, :, 0], cmap='viridis')
plt.title('Input Feature (first channel)')
plt.colorbar()

plt.subplot(1, 3, 2)
plt.imshow(y_train[:, :, 0], cmap='plasma', vmin=y_train.min(), vmax=y_train.max())
plt.title('True Target')
plt.colorbar()

plt.subplot(1, 3, 3)
plt.imshow(prediction[:, :, 0], cmap='plasma', vmin=y_train.min(), vmax=y_train.max())
plt.title('Predicted Target')
plt.colorbar()
plt.tight_layout()
plt.show()

# If you need to denormalize the prediction
# Use the metadata from your data preparation step
denormalized_prediction = prediction * metadata['Tmrt']['std'] + metadata['Tmrt']['mean']
# Out:
# Original data shape: X=(1000, 1000, 4), y=(1000, 1000, 1)
# Created 7216 patches of size 16x16
# Patches shape: X=(7216, 16, 16, 4), y=(7216, 16, 16, 1)
# Model: "functional_13"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_13      │ (None, 16, 16, 4) │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_94 (Conv2D)  │ (None, 16, 16,    │      2,368 │ input_layer_13[0… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │        256 │ conv2d_94[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_95 (Conv2D)  │ (None, 16, 16,    │     36,928 │ batch_normalizat… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │        256 │ conv2d_95[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_19    │ (None, 8, 8, 64)  │          0 │ batch_normalizat… │
# │ (MaxPooling2D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_96 (Conv2D)  │ (None, 8, 8, 128) │     73,856 │ max_pooling2d_19… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 8, 8, 128) │        512 │ conv2d_96[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_97 (Conv2D)  │ (None, 8, 8, 128) │    147,584 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 8, 8, 128) │        512 │ conv2d_97[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_20    │ (None, 4, 4, 128) │          0 │ batch_normalizat… │
# │ (MaxPooling2D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_98 (Conv2D)  │ (None, 4, 4, 256) │    295,168 │ max_pooling2d_20… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 4, 4, 256) │      1,024 │ conv2d_98[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_99 (Conv2D)  │ (None, 4, 4, 256) │    590,080 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 4, 4, 256) │      1,024 │ conv2d_99[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_19 │ (None, 8, 8, 128) │    131,200 │ batch_normalizat… │
# │ (Conv2DTranspose)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_19      │ (None, 8, 8, 256) │          0 │ conv2d_transpose… │
# │ (Concatenate)       │                   │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_100 (Conv2D) │ (None, 8, 8, 128) │    295,040 │ concatenate_19[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 8, 8, 128) │        512 │ conv2d_100[0][0]  │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_101 (Conv2D) │ (None, 8, 8, 128) │    147,584 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 8, 8, 128) │        512 │ conv2d_101[0][0]  │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_20 │ (None, 16, 16,    │     32,832 │ batch_normalizat… │
# │ (Conv2DTranspose)   │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_20      │ (None, 16, 16,    │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 128)              │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_102 (Conv2D) │ (None, 16, 16,    │     73,792 │ concatenate_20[0… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │        256 │ conv2d_102[0][0]  │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_103 (Conv2D) │ (None, 16, 16,    │     36,928 │ batch_normalizat… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │        256 │ conv2d_103[0][0]  │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_104 (Conv2D) │ (None, 16, 16, 1) │         65 │ batch_normalizat… │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 1,868,545 (7.13 MB)
#  Trainable params: 1,865,985 (7.12 MB)
#  Non-trainable params: 2,560 (10.00 KB)
# Epoch 1/100
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 12s 9ms/step - loss: 0.3819 - mae: 0.4141 - mse: 0.3819 - learning_rate: 0.0010
# Epoch 2/100
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - loss: 0.1147 - mae: 0.2359 - mse: 0.1147 - learning_rate: 0.0010
# Epoch 3/100
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - loss: 0.0986 - mae: 0.2180 - mse: 0.0986 - learning_rate: 0.0010
# Epoch 4/100
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - loss: 0.0803 - mae: 0.1999 - mse: 0.0803 - learning_rate: 0.0010
# Epoch 5/100
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - loss: 0.0779 - mae: 0.1987 - mse: 0.0779 - learning_rate: 0.0010
# Epoch 6/100
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - loss: 0.0693 - mae: 0.1856 - mse: 0.0693 - learning_rate: 0.0010
# Epoch 7/100
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 0.0684 - mae: 0.1853 - mse: 0.0684 - learning_rate: 0.0010
# Epoch 8/100
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - loss: 0.0656 - mae: 0.1833 - mse: 0.0656 - learning_rate: 0.0010
# Epoch 9/100
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - loss: 0.0569 - mae: 0.1693 - mse: 0.0569 - learning_rate: 0.0010
# Epoch 10/100
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - loss: 0.0562 - mae: 0.1703 - mse: 0.0562 - learning_rate: 0.0010
# Epoch 11/100
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 0.0532 - mae: 0.1655 - mse: 0.0532 - learning_rate: 0.0010
# Epoch 12/100
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 0.0562 - mae: 0.1698 - mse: 0.0562 - learning_rate: 0.0010
# Epoch 13/100
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 0.0467 - mae: 0.1551 - mse: 0.0467 - learning_rate: 0.0010
# Epoch 14/100
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.0490 - mae: 0.1585 - mse: 0.0490 - learning_rate: 0.0010
# Epoch 15/100
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - loss: 0.0493 - mae: 0.1594 - mse: 0.0493 - learning_rate: 0.0010
# Epoch 16/100
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - loss: 0.0462 - mae: 0.1541 - mse: 0.0462 - learning_rate: 0.0010
# Epoch 17/100
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - loss: 0.0431 - mae: 0.1491 - mse: 0.0431 - learning_rate: 0.0010
# Epoch 18/100
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - loss: 0.0405 - mae: 0.1479 - mse: 0.0405 - learning_rate: 0.0010
# Epoch 19/100
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 0.0401 - mae: 0.1459 - mse: 0.0401 - learning_rate: 0.0010
# Epoch 20/100
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - loss: 0.0365 - mae: 0.1398 - mse: 0.0365 - learning_rate: 0.0010
# Epoch 21/100
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 0.0409 - mae: 0.1471 - mse: 0.0409 - learning_rate: 0.0010
# Epoch 22/100
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.0409 - mae: 0.1483 - mse: 0.0409 - learning_rate: 0.0010
# Epoch 23/100
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.0321 - mae: 0.1318 - mse: 0.0321 - learning_rate: 0.0010
# Epoch 24/100
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 0.0338 - mae: 0.1365 - mse: 0.0338 - learning_rate: 0.0010
# Epoch 25/100
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 0.0350 - mae: 0.1384 - mse: 0.0350 - learning_rate: 0.0010
# Epoch 26/100
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - loss: 0.0306 - mae: 0.1281 - mse: 0.0306 - learning_rate: 0.0010
# Epoch 27/100
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - loss: 0.0333 - mae: 0.1342 - mse: 0.0333 - learning_rate: 0.0010
# Epoch 28/100
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.0283 - mae: 0.1252 - mse: 0.0283 - learning_rate: 0.0010
# Epoch 29/100
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - loss: 0.0316 - mae: 0.1318 - mse: 0.0316 - learning_rate: 0.0010
# Epoch 30/100
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 0.0262 - mae: 0.1214 - mse: 0.0262 - learning_rate: 0.0010
# Epoch 31/100
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - loss: 0.0263 - mae: 0.1217 - mse: 0.0263 - learning_rate: 0.0010
# Epoch 32/100
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - loss: 0.0256 - mae: 0.1208 - mse: 0.0256 - learning_rate: 0.0010
# Epoch 33/100
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - loss: 0.0286 - mae: 0.1252 - mse: 0.0286 - learning_rate: 0.0010
# Epoch 34/100
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - loss: 0.0266 - mae: 0.1229 - mse: 0.0266 - learning_rate: 0.0010
# Epoch 35/100
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - loss: 0.0247 - mae: 0.1185 - mse: 0.0247 - learning_rate: 0.0010
# Epoch 36/100
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - loss: 0.0266 - mae: 0.1234 - mse: 0.0266 - learning_rate: 0.0010
# Epoch 37/100
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - loss: 0.0257 - mae: 0.1196 - mse: 0.0257 - learning_rate: 0.0010
# Epoch 38/100
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 0.0253 - mae: 0.1207 - mse: 0.0253 - learning_rate: 0.0010
# Epoch 39/100
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - loss: 0.0235 - mae: 0.1172 - mse: 0.0235 - learning_rate: 0.0010
# Epoch 40/100
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 0.0228 - mae: 0.1149 - mse: 0.0228 - learning_rate: 0.0010
# Epoch 41/100
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - loss: 0.0245 - mae: 0.1198 - mse: 0.0245 - learning_rate: 0.0010
# Epoch 42/100
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - loss: 0.0275 - mae: 0.1254 - mse: 0.0275 - learning_rate: 0.0010
# Epoch 43/100
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - loss: 0.0241 - mae: 0.1183 - mse: 0.0241 - learning_rate: 0.0010
# Epoch 44/100
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.0231 - mae: 0.1159 - mse: 0.0231 - learning_rate: 0.0010
# Epoch 45/100
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - loss: 0.0225 - mae: 0.1158 - mse: 0.0225 - learning_rate: 0.0010
# Epoch 46/100
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - loss: 0.0204 - mae: 0.1093 - mse: 0.0204 - learning_rate: 0.0010
# Epoch 47/100
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.0209 - mae: 0.1112 - mse: 0.0209 - learning_rate: 0.0010
# Epoch 48/100
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - loss: 0.0196 - mae: 0.1079 - mse: 0.0196 - learning_rate: 0.0010
# Epoch 49/100
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 0.0243 - mae: 0.1200 - mse: 0.0243 - learning_rate: 0.0010
# Epoch 50/100
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 0.0190 - mae: 0.1049 - mse: 0.0190 - learning_rate: 0.0010
# Epoch 51/100
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 0.0211 - mae: 0.1115 - mse: 0.0211 - learning_rate: 0.0010
# Epoch 52/100
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 0.0227 - mae: 0.1143 - mse: 0.0227 - learning_rate: 0.0010
# Epoch 53/100
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.0194 - mae: 0.1062 - mse: 0.0194 - learning_rate: 0.0010
# Epoch 54/100
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.0215 - mae: 0.1111 - mse: 0.0215 - learning_rate: 0.0010
# Epoch 55/100
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 0.0201 - mae: 0.1069 - mse: 0.0201 - learning_rate: 0.0010
# Epoch 56/100
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - loss: 0.0201 - mae: 0.1091 - mse: 0.0201 - learning_rate: 5.0000e-04
# Epoch 57/100
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - loss: 0.0199 - mae: 0.1099 - mse: 0.0199 - learning_rate: 5.0000e-04
# Epoch 58/100
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 0.0191 - mae: 0.1054 - mse: 0.0191 - learning_rate: 5.0000e-04
# Epoch 59/100
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - loss: 0.0167 - mae: 0.1002 - mse: 0.0167 - learning_rate: 5.0000e-04
# Epoch 60/100
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - loss: 0.0172 - mae: 0.1015 - mse: 0.0172 - learning_rate: 5.0000e-04
# Epoch 61/100
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 0.0175 - mae: 0.1023 - mse: 0.0175 - learning_rate: 5.0000e-04
# Epoch 62/100
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - loss: 0.0161 - mae: 0.0990 - mse: 0.0161 - learning_rate: 5.0000e-04
# Epoch 63/100
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.0164 - mae: 0.1001 - mse: 0.0164 - learning_rate: 5.0000e-04
# Epoch 64/100
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - loss: 0.0163 - mae: 0.0984 - mse: 0.0163 - learning_rate: 5.0000e-04
# Epoch 65/100
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - loss: 0.0165 - mae: 0.1007 - mse: 0.0165 - learning_rate: 2.5000e-04
# Epoch 66/100
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - loss: 0.0164 - mae: 0.0995 - mse: 0.0164 - learning_rate: 2.5000e-04
# Epoch 67/100
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.0167 - mae: 0.1015 - mse: 0.0167 - learning_rate: 2.5000e-04
# Epoch 68/100
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 0.0151 - mae: 0.0965 - mse: 0.0151 - learning_rate: 2.5000e-04
# Epoch 69/100
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - loss: 0.0156 - mae: 0.0976 - mse: 0.0156 - learning_rate: 2.5000e-04
# Epoch 70/100
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - loss: 0.0153 - mae: 0.0977 - mse: 0.0153 - learning_rate: 2.5000e-04
# Epoch 71/100
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - loss: 0.0151 - mae: 0.0955 - mse: 0.0151 - learning_rate: 2.5000e-04
# Epoch 72/100
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 0.0157 - mae: 0.0969 - mse: 0.0157 - learning_rate: 2.5000e-04
# Epoch 73/100
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - loss: 0.0145 - mae: 0.0944 - mse: 0.0145 - learning_rate: 2.5000e-04
# Epoch 74/100
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - loss: 0.0152 - mae: 0.0972 - mse: 0.0152 - learning_rate: 2.5000e-04
# Epoch 75/100
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - loss: 0.0148 - mae: 0.0954 - mse: 0.0148 - learning_rate: 2.5000e-04
# Epoch 76/100
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - loss: 0.0161 - mae: 0.0996 - mse: 0.0161 - learning_rate: 2.5000e-04
# Epoch 77/100
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 0.0137 - mae: 0.0923 - mse: 0.0137 - learning_rate: 2.5000e-04
# Epoch 78/100
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 0.0152 - mae: 0.0972 - mse: 0.0152 - learning_rate: 2.5000e-04
# Epoch 79/100
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - loss: 0.0163 - mae: 0.1000 - mse: 0.0163 - learning_rate: 2.5000e-04
# Epoch 80/100
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 0.0158 - mae: 0.0981 - mse: 0.0158 - learning_rate: 2.5000e-04
# Epoch 81/100
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - loss: 0.0157 - mae: 0.0984 - mse: 0.0157 - learning_rate: 2.5000e-04
# Epoch 82/100
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - loss: 0.0143 - mae: 0.0931 - mse: 0.0143 - learning_rate: 2.5000e-04
# Epoch 83/100
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - loss: 0.0141 - mae: 0.0935 - mse: 0.0141 - learning_rate: 1.2500e-04
# Epoch 84/100
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 0.0132 - mae: 0.0905 - mse: 0.0132 - learning_rate: 1.2500e-04
# Epoch 85/100
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - loss: 0.0139 - mae: 0.0933 - mse: 0.0139 - learning_rate: 1.2500e-04
# Epoch 86/100
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - loss: 0.0133 - mae: 0.0896 - mse: 0.0133 - learning_rate: 1.2500e-04
# Epoch 87/100
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 0.0151 - mae: 0.0970 - mse: 0.0151 - learning_rate: 1.2500e-04
# Epoch 88/100
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 0.0138 - mae: 0.0915 - mse: 0.0138 - learning_rate: 1.2500e-04
# Epoch 89/100
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.0148 - mae: 0.0965 - mse: 0.0148 - learning_rate: 1.2500e-04
# Epoch 90/100
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.0143 - mae: 0.0941 - mse: 0.0143 - learning_rate: 1.2500e-04
# Epoch 91/100
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - loss: 0.0142 - mae: 0.0908 - mse: 0.0142 - learning_rate: 1.2500e-04
# Epoch 92/100
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - loss: 0.0135 - mae: 0.0917 - mse: 0.0135 - learning_rate: 6.2500e-05
# Epoch 93/100
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - loss: 0.0145 - mae: 0.0955 - mse: 0.0145 - learning_rate: 6.2500e-05
# Epoch 94/100
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - loss: 0.0132 - mae: 0.0900 - mse: 0.0132 - learning_rate: 6.2500e-05
# Epoch 95/100
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - loss: 0.0139 - mae: 0.0938 - mse: 0.0139 - learning_rate: 6.2500e-05
# Epoch 96/100
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - loss: 0.0152 - mae: 0.0988 - mse: 0.0152 - learning_rate: 6.2500e-05

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras import layers, models
import os

# Extremely simplified U-Net model
def create_minimal_unet(input_shape):
    """Create a minimal U-Net model with just enough complexity for four input rasters."""
    inputs = layers.Input(shape=input_shape)
    
    # Encoder: single downsampling path
    conv1 = layers.Conv2D(16, (3, 3), activation='relu', padding='same')(inputs)
    pool1 = layers.MaxPooling2D(pool_size=(2, 2))(conv1)
    
    # Bridge
    conv2 = layers.Conv2D(32, (3, 3), activation='relu', padding='same')(pool1)
    
    # Decoder: single upsampling path
    up1 = layers.Conv2DTranspose(16, (2, 2), strides=(2, 2), padding='same')(conv2)
    concat1 = layers.Concatenate()([up1, conv1])
    conv3 = layers.Conv2D(16, (3, 3), activation='relu', padding='same')(concat1)
    
    # Output
    outputs = layers.Conv2D(1, (1, 1), activation='linear')(conv3)
    
    # Create and compile model
    model = models.Model(inputs=inputs, outputs=outputs)
    model.compile(optimizer='adam', loss='mse', metrics=['mae'])
    
    return model

def load_raster(file_path):
    """Load a single-band raster file as a numpy array."""
    with rasterio.open(file_path) as src:
        return src.read(1)
    
# Function to load sample raster data
def load_sample_data(generate=False, height=128, width=128):
    """Load sample raster data."""
    tilenr = "02_04"
    data_dir = Path("data") / "static" / tilenr

    X_data = np.stack([
        load_raster(data_dir / f"SkyViewFactor_{tilenr}.tif"),
        load_raster(data_dir / f"wall_height_{tilenr}.tif"),
        load_raster(data_dir / f"wall_aspect_{tilenr}.tif"),
        load_raster(data_dir / f"DO_landcover_3m_reclassified_final_{tilenr}.tif")
    ], axis=-1)
    y_data = load_raster(data_dir / f"{tilenr}_Tmrt_3m_v0.6.0_2024_093_1000D.tif")[:,:,np.newaxis]
    
    return X_data, y_data

# Main function
def train_and_visualize():
    """Load data, train model, and visualize results."""
    # 1. Load/generate data
    X_data, y_data = load_sample_data(generate=False, height=128, width=128)
    print(f"Data shapes: X={X_data.shape}, y={y_data.shape}")

    # Normalize data
    X_data = (X_data - np.nanmean(X_data)) / np.nanstd(X_data)
    y_data = (y_data - np.nanmean(y_data)) / np.nanstd(y_data)
    
    # 2. Create model
    model = create_minimal_unet((X_data.shape[0], X_data.shape[1], X_data.shape[2]))
    model.summary()
    
    # 3. Train model (using the full raster, no patches for simplicity)
    # Add batch dimension
    X_data_batch = np.expand_dims(X_data, axis=0)
    y_data_batch = np.expand_dims(y_data, axis=0)
    
    # Simple training with early stopping
    callback = tf.keras.callbacks.EarlyStopping(monitor='loss', patience=5)
    history = model.fit(
        X_data_batch, y_data_batch,
        batch_size=50,
        epochs=1000,
        callbacks=[callback]
    )
    
    # 4. Make prediction
    prediction = model.predict(X_data_batch)[0]  # Remove batch dimension
    
    # 5. Visualize results
    # Input rasters
    plt.figure(figsize=(12, 8))
    titles = ['Input 1', 'Input 2', 'Input 3', 'Input 4']
    
    for i in range(4):
        plt.subplot(2, 3, i+1)
        plt.imshow(X_data[:,:,i], cmap='viridis')
        plt.title(titles[i])
        plt.colorbar()
    
    # Ground truth vs prediction
    plt.subplot(2, 3, 5)
    plt.imshow(y_data[:,:,0], cmap='plasma')
    plt.title('Ground Truth')
    plt.colorbar()
    
    plt.subplot(2, 3, 6)
    plt.imshow(prediction[:,:,0], cmap='plasma')
    plt.title('Prediction')
    plt.colorbar()
    
    plt.tight_layout()
    plt.savefig('results.png')
    plt.show()
    
    # Plot training history
    plt.figure(figsize=(10, 4))
    plt.plot(history.history['loss'])
    plt.title('Model Loss')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.savefig('training.png')
    plt.show()
    
    return model, prediction

if __name__ == "__main__":
    # Set GPU memory growth to avoid OOM errors
    gpus = tf.config.list_physical_devices('GPU')
    if gpus:
        print(f"GPU available: {gpus}")
    else:
        print("No GPU found, using CPU.")
    
    # Run training and visualization
    model, prediction = train_and_visualize()
# Out:
# GPU available: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# Data shapes: X=(1000, 1000, 4), y=(1000, 1000, 1)
# Model: "functional_8"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_8       │ (None, 1000,      │          0 │ -                 │
# │ (InputLayer)        │ 1000, 4)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_46 (Conv2D)  │ (None, 1000,      │        592 │ input_layer_8[0]… │
# │                     │ 1000, 16)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_10    │ (None, 500, 500,  │          0 │ conv2d_46[0][0]   │
# │ (MaxPooling2D)      │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_47 (Conv2D)  │ (None, 500, 500,  │      4,640 │ max_pooling2d_10… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_10 │ (None, 1000,      │      2,064 │ conv2d_47[0][0]   │
# │ (Conv2DTranspose)   │ 1000, 16)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_10      │ (None, 1000,      │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 1000, 32)         │            │ conv2d_46[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_48 (Conv2D)  │ (None, 1000,      │      4,624 │ concatenate_10[0… │
# │                     │ 1000, 16)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_49 (Conv2D)  │ (None, 1000,      │         17 │ conv2d_48[0][0]   │
# │                     │ 1000, 1)          │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 11,937 (46.63 KB)
#  Trainable params: 11,937 (46.63 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step - loss: 1.4969 - mae: 0.8799
# Epoch 2/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 1.1687 - mae: 0.8149
# Epoch 3/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 0.9981 - mae: 0.7777
# Epoch 4/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 0.9468 - mae: 0.7679
# Epoch 5/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 0.9613 - mae: 0.7733
# Epoch 6/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 0.9806 - mae: 0.7787
# Epoch 7/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 0.9766 - mae: 0.7775
# Epoch 8/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.9514 - mae: 0.7704
# Epoch 9/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.9174 - mae: 0.7604
# Epoch 10/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 0.8862 - mae: 0.7504
# Epoch 11/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.8652 - mae: 0.7429
# Epoch 12/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 0.8562 - mae: 0.7387
# Epoch 13/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.8553 - mae: 0.7371
# Epoch 14/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.8562 - mae: 0.7365
# Epoch 15/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.8538 - mae: 0.7355
# Epoch 16/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.8473 - mae: 0.7335
# Epoch 17/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 0.8388 - mae: 0.7311
# Epoch 18/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.8309 - mae: 0.7290
# Epoch 19/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.8252 - mae: 0.7276
# Epoch 20/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.8212 - mae: 0.7266
# Epoch 21/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 0.8179 - mae: 0.7257
# Epoch 22/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 0.8142 - mae: 0.7247
# Epoch 23/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.8098 - mae: 0.7233
# Epoch 24/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 0.8050 - mae: 0.7216
# Epoch 25/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.8003 - mae: 0.7199
# Epoch 26/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 0.7963 - mae: 0.7184
# Epoch 27/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 0.7932 - mae: 0.7171
# Epoch 28/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.7909 - mae: 0.7160
# Epoch 29/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 0.7891 - mae: 0.7152
# Epoch 30/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.7870 - mae: 0.7143
# Epoch 31/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.7842 - mae: 0.7134
# Epoch 32/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 0.7809 - mae: 0.7124
# Epoch 33/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.7775 - mae: 0.7115
# Epoch 34/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 0.7745 - mae: 0.7107
# Epoch 35/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.7720 - mae: 0.7100
# Epoch 36/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 0.7698 - mae: 0.7093
# Epoch 37/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.7677 - mae: 0.7086
# Epoch 38/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 0.7657 - mae: 0.7079
# Epoch 39/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 0.7637 - mae: 0.7071
# Epoch 40/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.7617 - mae: 0.7062
# Epoch 41/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 0.7596 - mae: 0.7053
# Epoch 42/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 0.7573 - mae: 0.7043
# Epoch 43/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.7550 - mae: 0.7032
# Epoch 44/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 0.7526 - mae: 0.7021
# Epoch 45/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.7502 - mae: 0.7010
# Epoch 46/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 0.7479 - mae: 0.6998
# Epoch 47/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 0.7456 - mae: 0.6986
# Epoch 48/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 0.7434 - mae: 0.6974
# Epoch 49/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.7411 - mae: 0.6961
# Epoch 50/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.7387 - mae: 0.6947
# Epoch 51/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.7362 - mae: 0.6933
# Epoch 52/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.7338 - mae: 0.6918
# Epoch 53/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.7313 - mae: 0.6903
# Epoch 54/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 0.7288 - mae: 0.6889
# Epoch 55/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 0.7264 - mae: 0.6874
# Epoch 56/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 0.7239 - mae: 0.6860
# Epoch 57/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.7214 - mae: 0.6845
# Epoch 58/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.7188 - mae: 0.6830
# Epoch 59/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.7162 - mae: 0.6814
# Epoch 60/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 0.7135 - mae: 0.6799
# Epoch 61/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 0.7107 - mae: 0.6783
# Epoch 62/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 0.7080 - mae: 0.6766
# Epoch 63/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.7052 - mae: 0.6749
# Epoch 64/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.7024 - mae: 0.6732
# Epoch 65/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.6995 - mae: 0.6715
# Epoch 66/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.6966 - mae: 0.6696
# Epoch 67/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.6936 - mae: 0.6677
# Epoch 68/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.6906 - mae: 0.6658
# Epoch 69/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 0.6875 - mae: 0.6637
# Epoch 70/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 0.6843 - mae: 0.6616
# Epoch 71/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.6812 - mae: 0.6594
# Epoch 72/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 0.6780 - mae: 0.6572
# Epoch 73/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 0.6748 - mae: 0.6550
# Epoch 74/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 0.6715 - mae: 0.6527
# Epoch 75/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.6682 - mae: 0.6505
# Epoch 76/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 0.6649 - mae: 0.6482
# Epoch 77/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 0.6615 - mae: 0.6458
# Epoch 78/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.6580 - mae: 0.6433
# Epoch 79/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.6546 - mae: 0.6408
# Epoch 80/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.6511 - mae: 0.6383
# Epoch 81/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.6475 - mae: 0.6358
# Epoch 82/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 0.6438 - mae: 0.6332
# Epoch 83/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 0.6400 - mae: 0.6306
# Epoch 84/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 0.6360 - mae: 0.6279
# Epoch 85/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.6319 - mae: 0.6251
# Epoch 86/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.6275 - mae: 0.6221
# Epoch 87/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.6230 - mae: 0.6189
# Epoch 88/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 0.6185 - mae: 0.6157
# Epoch 89/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.6139 - mae: 0.6124
# Epoch 90/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.6092 - mae: 0.6089
# Epoch 91/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.6043 - mae: 0.6054
# Epoch 92/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.5993 - mae: 0.6018
# Epoch 93/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.5941 - mae: 0.5980
# Epoch 94/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 0.5890 - mae: 0.5940
# Epoch 95/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.5846 - mae: 0.5911
# Epoch 96/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.5795 - mae: 0.5882
# Epoch 97/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.5749 - mae: 0.5849
# Epoch 98/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.5706 - mae: 0.5804
# Epoch 99/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 0.5665 - mae: 0.5763
# Epoch 100/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.5624 - mae: 0.5735
# Epoch 101/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.5586 - mae: 0.5712
# Epoch 102/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.5547 - mae: 0.5677
# Epoch 103/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.5510 - mae: 0.5633
# Epoch 104/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.5473 - mae: 0.5601
# Epoch 105/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 0.5441 - mae: 0.5583
# Epoch 106/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.5413 - mae: 0.5559
# Epoch 107/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 0.5386 - mae: 0.5525
# Epoch 108/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 0.5360 - mae: 0.5497
# Epoch 109/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.5336 - mae: 0.5482
# Epoch 110/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.5314 - mae: 0.5462
# Epoch 111/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.5294 - mae: 0.5438
# Epoch 112/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.5275 - mae: 0.5420
# Epoch 113/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.5256 - mae: 0.5408
# Epoch 114/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 0.5239 - mae: 0.5391
# Epoch 115/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 0.5222 - mae: 0.5368
# Epoch 116/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.5206 - mae: 0.5354
# Epoch 117/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.5189 - mae: 0.5344
# Epoch 118/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.5173 - mae: 0.5333
# Epoch 119/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.5159 - mae: 0.5316
# Epoch 120/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.5145 - mae: 0.5304
# Epoch 121/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 0.5132 - mae: 0.5300
# Epoch 122/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 0.5119 - mae: 0.5292
# Epoch 123/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.5108 - mae: 0.5277
# Epoch 124/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.5096 - mae: 0.5266
# Epoch 125/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 0.5083 - mae: 0.5258
# Epoch 126/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.5072 - mae: 0.5249
# Epoch 127/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.5061 - mae: 0.5241
# Epoch 128/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 0.5050 - mae: 0.5235
# Epoch 129/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 0.5040 - mae: 0.5230
# Epoch 130/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.5030 - mae: 0.5226
# Epoch 131/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 0.5020 - mae: 0.5222
# Epoch 132/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 0.5012 - mae: 0.5217
# Epoch 133/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.5002 - mae: 0.5215
# Epoch 134/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 0.4993 - mae: 0.5211
# Epoch 135/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 0.4985 - mae: 0.5205
# Epoch 136/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.4977 - mae: 0.5202
# Epoch 137/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 0.4968 - mae: 0.5200
# Epoch 138/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 0.4960 - mae: 0.5195
# Epoch 139/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.4952 - mae: 0.5190
# Epoch 140/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.4944 - mae: 0.5188
# Epoch 141/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.4936 - mae: 0.5185
# Epoch 142/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 0.4928 - mae: 0.5179
# Epoch 143/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 0.4921 - mae: 0.5177
# Epoch 144/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 0.4913 - mae: 0.5175
# Epoch 145/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.4906 - mae: 0.5170
# Epoch 146/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 0.4898 - mae: 0.5167
# Epoch 147/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 0.4891 - mae: 0.5165
# Epoch 148/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 0.4883 - mae: 0.5160
# Epoch 149/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 0.4876 - mae: 0.5156
# Epoch 150/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 0.4869 - mae: 0.5154
# Epoch 151/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 0.4862 - mae: 0.5150
# Epoch 152/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 0.4854 - mae: 0.5145
# Epoch 153/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 0.4847 - mae: 0.5142
# Epoch 154/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.4840 - mae: 0.5139
# Epoch 155/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 0.4833 - mae: 0.5135
# Epoch 156/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.4827 - mae: 0.5133
# Epoch 157/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.4819 - mae: 0.5129
# Epoch 158/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.4812 - mae: 0.5125
# Epoch 159/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.4805 - mae: 0.5123
# Epoch 160/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.4799 - mae: 0.5120
# Epoch 161/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.4792 - mae: 0.5117
# Epoch 162/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 0.4786 - mae: 0.5115
# Epoch 163/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.4779 - mae: 0.5111
# Epoch 164/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 0.4772 - mae: 0.5108
# Epoch 165/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 0.4766 - mae: 0.5106
# Epoch 166/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 0.4759 - mae: 0.5102
# Epoch 167/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 0.4753 - mae: 0.5099
# Epoch 168/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 0.4747 - mae: 0.5097
# Epoch 169/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.4740 - mae: 0.5093
# Epoch 170/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 0.4734 - mae: 0.5091
# Epoch 171/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 0.4728 - mae: 0.5088
# Epoch 172/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 0.4721 - mae: 0.5084
# Epoch 173/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.4715 - mae: 0.5082
# Epoch 174/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 0.4709 - mae: 0.5079
# Epoch 175/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 0.4702 - mae: 0.5076
# Epoch 176/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 0.4696 - mae: 0.5074
# Epoch 177/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 0.4690 - mae: 0.5071
# Epoch 178/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.4684 - mae: 0.5069
# Epoch 179/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.4678 - mae: 0.5066
# Epoch 180/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 0.4672 - mae: 0.5064
# Epoch 181/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.4666 - mae: 0.5063
# Epoch 182/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.4660 - mae: 0.5059
# Epoch 183/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 0.4654 - mae: 0.5058
# Epoch 184/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 0.4648 - mae: 0.5055
# Epoch 185/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 0.4642 - mae: 0.5052
# Epoch 186/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 0.4636 - mae: 0.5050
# Epoch 187/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.4630 - mae: 0.5046
# Epoch 188/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.4624 - mae: 0.5044
# Epoch 189/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 0.4618 - mae: 0.5039
# Epoch 190/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 0.4611 - mae: 0.5036
# Epoch 191/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.4605 - mae: 0.5033
# Epoch 192/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.4599 - mae: 0.5030
# Epoch 193/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 0.4593 - mae: 0.5028
# Epoch 194/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.4587 - mae: 0.5026
# Epoch 195/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.4581 - mae: 0.5023
# Epoch 196/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.4575 - mae: 0.5021
# Epoch 197/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 0.4569 - mae: 0.5018
# Epoch 198/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 0.4563 - mae: 0.5016
# Epoch 199/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 0.4557 - mae: 0.5012
# Epoch 200/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 0.4551 - mae: 0.5011
# Epoch 201/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.4544 - mae: 0.5005
# Epoch 202/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 0.4538 - mae: 0.5006
# Epoch 203/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 0.4532 - mae: 0.4997
# Epoch 204/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.4526 - mae: 0.5001
# Epoch 205/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 0.4520 - mae: 0.4988
# Epoch 206/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.4514 - mae: 0.5000
# Epoch 207/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 0.4508 - mae: 0.4979
# Epoch 208/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - loss: 0.4502 - mae: 0.4995
# Epoch 209/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.4494 - mae: 0.4974
# Epoch 210/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.4484 - mae: 0.4980
# Epoch 211/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 0.4478 - mae: 0.4976
# Epoch 212/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.4472 - mae: 0.4966
# Epoch 213/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 0.4465 - mae: 0.4976
# Epoch 214/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.4458 - mae: 0.4957
# Epoch 215/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.4450 - mae: 0.4964
# Epoch 216/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 0.4442 - mae: 0.4955
# Epoch 217/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 0.4435 - mae: 0.4948
# Epoch 218/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.4428 - mae: 0.4954
# Epoch 219/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 0.4420 - mae: 0.4938
# Epoch 220/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.4412 - mae: 0.4944
# Epoch 221/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.4404 - mae: 0.4932
# Epoch 222/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.4397 - mae: 0.4929
# Epoch 223/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 0.4389 - mae: 0.4928
# Epoch 224/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 0.4382 - mae: 0.4918
# Epoch 225/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.4374 - mae: 0.4922
# Epoch 226/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.4367 - mae: 0.4907
# Epoch 227/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.4359 - mae: 0.4910
# Epoch 228/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 0.4351 - mae: 0.4899
# Epoch 229/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.4343 - mae: 0.4897
# Epoch 230/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.4335 - mae: 0.4893
# Epoch 231/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.4327 - mae: 0.4885
# Epoch 232/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 0.4319 - mae: 0.4888
# Epoch 233/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.4311 - mae: 0.4874
# Epoch 234/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.4302 - mae: 0.4879
# Epoch 235/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.4294 - mae: 0.4864
# Epoch 236/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.4285 - mae: 0.4868
# Epoch 237/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.4275 - mae: 0.4853
# Epoch 238/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.4266 - mae: 0.4857
# Epoch 239/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.4257 - mae: 0.4841
# Epoch 240/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 0.4248 - mae: 0.4844
# Epoch 241/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.4238 - mae: 0.4827
# Epoch 242/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.4229 - mae: 0.4834
# Epoch 243/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.4221 - mae: 0.4813
# Epoch 244/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.4212 - mae: 0.4831
# Epoch 245/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.4204 - mae: 0.4799
# Epoch 246/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.4196 - mae: 0.4826
# Epoch 247/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.4186 - mae: 0.4786
# Epoch 248/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.4173 - mae: 0.4805
# Epoch 249/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 0.4160 - mae: 0.4782
# Epoch 250/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 0.4150 - mae: 0.4777
# Epoch 251/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 0.4142 - mae: 0.4784
# Epoch 252/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 0.4133 - mae: 0.4754
# Epoch 253/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 0.4123 - mae: 0.4775
# Epoch 254/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.4111 - mae: 0.4741
# Epoch 255/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.4099 - mae: 0.4750
# Epoch 256/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 0.4088 - mae: 0.4737
# Epoch 257/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 0.4079 - mae: 0.4722
# Epoch 258/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 0.4069 - mae: 0.4733
# Epoch 259/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 0.4060 - mae: 0.4702
# Epoch 260/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.4050 - mae: 0.4720
# Epoch 261/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - loss: 0.4039 - mae: 0.4691
# Epoch 262/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.4028 - mae: 0.4695
# Epoch 263/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 0.4018 - mae: 0.4683
# Epoch 264/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.4008 - mae: 0.4671
# Epoch 265/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.3999 - mae: 0.4677
# Epoch 266/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 0.3990 - mae: 0.4653
# Epoch 267/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 0.3981 - mae: 0.4670
# Epoch 268/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 0.3972 - mae: 0.4635
# Epoch 269/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - loss: 0.3962 - mae: 0.4655
# Epoch 270/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 0.3952 - mae: 0.4622
# Epoch 271/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 0.3941 - mae: 0.4637
# Epoch 272/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - loss: 0.3931 - mae: 0.4617
# Epoch 273/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.3921 - mae: 0.4613
# Epoch 274/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.3912 - mae: 0.4607
# Epoch 275/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.3904 - mae: 0.4588
# Epoch 276/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 0.3896 - mae: 0.4600
# Epoch 277/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 0.3889 - mae: 0.4569
# Epoch 278/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.3883 - mae: 0.4599
# Epoch 279/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.3878 - mae: 0.4551
# Epoch 280/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.3873 - mae: 0.4600
# Epoch 281/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.3866 - mae: 0.4534
# Epoch 282/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.3853 - mae: 0.4579
# Epoch 283/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - loss: 0.3839 - mae: 0.4530
# Epoch 284/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 0.3828 - mae: 0.4532
# Epoch 285/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 0.3823 - mae: 0.4542
# Epoch 286/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.3819 - mae: 0.4505
# Epoch 287/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.3811 - mae: 0.4541
# Epoch 288/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 0.3801 - mae: 0.4494
# Epoch 289/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - loss: 0.3790 - mae: 0.4510
# Epoch 290/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 0.3782 - mae: 0.4501
# Epoch 291/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 0.3776 - mae: 0.4478
# Epoch 292/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.3771 - mae: 0.4505
# Epoch 293/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 0.3763 - mae: 0.4460
# Epoch 294/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.3753 - mae: 0.4485
# Epoch 295/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.3744 - mae: 0.4454
# Epoch 296/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.3736 - mae: 0.4453
# Epoch 297/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.3729 - mae: 0.4462
# Epoch 298/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 0.3723 - mae: 0.4431
# Epoch 299/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 0.3716 - mae: 0.4456
# Epoch 300/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 0.3709 - mae: 0.4415
# Epoch 301/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.3701 - mae: 0.4443
# Epoch 302/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.3693 - mae: 0.4403
# Epoch 303/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.3684 - mae: 0.4420
# Epoch 304/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 0.3675 - mae: 0.4398
# Epoch 305/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.3667 - mae: 0.4396
# Epoch 306/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.3660 - mae: 0.4395
# Epoch 307/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.3652 - mae: 0.4377
# Epoch 308/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.3646 - mae: 0.4392
# Epoch 309/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.3641 - mae: 0.4354
# Epoch 310/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.3639 - mae: 0.4405
# Epoch 311/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.3640 - mae: 0.4334
# Epoch 312/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.3640 - mae: 0.4420
# Epoch 313/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 0.3633 - mae: 0.4325
# Epoch 314/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.3612 - mae: 0.4384
# Epoch 315/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 0.3592 - mae: 0.4327
# Epoch 316/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.3589 - mae: 0.4309
# Epoch 317/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 0.3591 - mae: 0.4362
# Epoch 318/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 0.3583 - mae: 0.4286
# Epoch 319/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.3566 - mae: 0.4322
# Epoch 320/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.3554 - mae: 0.4303
# Epoch 321/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.3554 - mae: 0.4275
# Epoch 322/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 0.3550 - mae: 0.4330
# Epoch 323/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 0.3536 - mae: 0.4261
# Epoch 324/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 0.3524 - mae: 0.4265
# Epoch 325/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 0.3519 - mae: 0.4276
# Epoch 326/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 0.3515 - mae: 0.4234
# Epoch 327/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 0.3506 - mae: 0.4268
# Epoch 328/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 0.3494 - mae: 0.4235
# Epoch 329/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 0.3486 - mae: 0.4233
# Epoch 330/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 0.3481 - mae: 0.4240
# Epoch 331/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.3475 - mae: 0.4201
# Epoch 332/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 0.3466 - mae: 0.4236
# Epoch 333/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.3456 - mae: 0.4192
# Epoch 334/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 0.3447 - mae: 0.4201
# Epoch 335/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 0.3439 - mae: 0.4195
# Epoch 336/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 0.3434 - mae: 0.4168
# Epoch 337/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.3429 - mae: 0.4210
# Epoch 338/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.3421 - mae: 0.4150
# Epoch 339/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.3411 - mae: 0.4182
# Epoch 340/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.3401 - mae: 0.4147
# Epoch 341/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.3393 - mae: 0.4146
# Epoch 342/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.3387 - mae: 0.4154
# Epoch 343/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.3381 - mae: 0.4119
# Epoch 344/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.3377 - mae: 0.4158
# Epoch 345/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.3372 - mae: 0.4099
# Epoch 346/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - loss: 0.3368 - mae: 0.4158
# Epoch 347/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.3361 - mae: 0.4085
# Epoch 348/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.3352 - mae: 0.4142
# Epoch 349/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 0.3342 - mae: 0.4074
# Epoch 350/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - loss: 0.3333 - mae: 0.4106
# Epoch 351/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.3324 - mae: 0.4075
# Epoch 352/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.3317 - mae: 0.4067
# Epoch 353/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.3313 - mae: 0.4083
# Epoch 354/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.3309 - mae: 0.4046
# Epoch 355/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.3307 - mae: 0.4100
# Epoch 356/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.3303 - mae: 0.4031
# Epoch 357/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.3299 - mae: 0.4097
# Epoch 358/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.3290 - mae: 0.4018
# Epoch 359/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 0.3281 - mae: 0.4070
# Epoch 360/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 0.3271 - mae: 0.4007
# Epoch 361/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 0.3261 - mae: 0.4032
# Epoch 362/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 0.3253 - mae: 0.4007
# Epoch 363/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 0.3247 - mae: 0.4008
# Epoch 364/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - loss: 0.3242 - mae: 0.4019
# Epoch 365/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 0.3236 - mae: 0.3993
# Epoch 366/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 0.3230 - mae: 0.4018
# Epoch 367/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 0.3222 - mae: 0.3977
# Epoch 368/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 0.3214 - mae: 0.4000
# Epoch 369/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.3206 - mae: 0.3968
# Epoch 370/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 0.3200 - mae: 0.3978
# Epoch 371/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 0.3194 - mae: 0.3954
# Epoch 372/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.3189 - mae: 0.3964
# Epoch 373/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 0.3184 - mae: 0.3943
# Epoch 374/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 0.3181 - mae: 0.3961
# Epoch 375/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.3182 - mae: 0.3937
# Epoch 376/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 0.3187 - mae: 0.3968
# Epoch 377/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 0.3193 - mae: 0.3958
# Epoch 378/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 0.3184 - mae: 0.3965
# Epoch 379/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 0.3161 - mae: 0.3944
# Epoch 380/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 0.3143 - mae: 0.3901
# Epoch 381/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.3146 - mae: 0.3941
# Epoch 382/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.3156 - mae: 0.3884
# Epoch 383/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 0.3156 - mae: 0.3973
# Epoch 384/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 0.3149 - mae: 0.3883
# Epoch 385/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 0.3147 - mae: 0.4003
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 243ms/step

# %%
# Now I want to save the model and prediction to disk
os.makedirs('models', exist_ok=True)
model.save('models/minimal_unet_model.keras')

# %%
# Apply the model to a different raster
